# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyagoyal1/Machine-Learning/blob/main/Image_Classification_review1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mounting Google Drive in Google Colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Installing Fastai and Dependencies**

# %%
# !pip install fastai==2.0.19
# !pip install torch
# !pip install torchvision

# %% [markdown]
# **Image Classification with Fastai and Sklearn: Analysis and Evaluation**

# %%
from fastai import *
from fastai.vision.all import *
from torchvision import transforms
from fastai.metrics import error_rate
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import csv
# !pip install Pathlib
from pathlib import Path
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, precision_recall_curve, auc, average_precision_score
from sklearn.preprocessing import label_binarize
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
# Out:
# Requirement already satisfied: Pathlib in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %% [markdown]
# **Listing Files in Directory Using Python Pathlib**

# %%
x  = r'/content/drive/MyDrive/EYE'
path = Path(x)
path.ls()
# Out:
# (#3) [Path('/content/drive/MyDrive/EYE/OPEN'),Path('/content/drive/MyDrive/EYE/CLOSED'),Path('/content/drive/MyDrive/EYE/Test')]

# %% [markdown]
# **Image Data Loading and Augmentation with PyTorch and Fastai**

# %%
np.random.seed(40)
data = ImageDataLoaders.from_folder(path, train = '.', valid_pct=0.2, item_tfms=Resize(460),
                                  batch_tfms=[*aug_transforms(size=224), Normalize.from_stats(*imagenet_stats)], size=224,
                                  num_workers=4)

# %% [markdown]
# **Visualizing Data Batch**

# %%
data.show_batch(nrows=3, figsize=(7,6))

# %%
data
print(data.vocab)
len(data.vocab)
data.c
# Out:
# ['CLOSED', 'OPEN', 'Test']
# 3

# %% [markdown]
# **Creating a Convolutional Neural Network (CNN) Learner with ResNet-18 Architecture**

# %%
learn = cnn_learner(data, models.resnet18, metrics=[accuracy], model_dir = Path('../kaggle/working'),path = Path("."))
# Out:
# /usr/local/lib/python3.10/dist-packages/fastai/vision/learner.py:301: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 150MB/s]

# %% [markdown]
# **Finding Optimal Learning Rate and Plotting Suggestions using Fastai's**

# %%
learn.lr_find()
learn.recorder.plot_lr_find(suggestions=True)(str(False))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f22139e3aced> in <cell line: 2>()
#       1 learn.lr_find()
# ----> 2 learn.recorder.plot_lr_find(suggestions=True)(str(False))
#
# /usr/local/lib/python3.10/dist-packages/fastai/callback/schedule.py in plot_lr_find(self, skip_end, return_fig, suggestions, nms, **kwargs)
#     277     if suggestions:
#     278         colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][1:]
# --> 279         for (val, idx), nm, color in zip(suggestions, nms, colors):
#     280             ax.plot(val, idx, 'o', label=nm, c=color)
#     281         ax.legend(loc='best')
#
# TypeError: 'bool' object is not iterable

# %% [markdown]
# **Training a Model with One Cycle Learning Rate Scheduling**

# %%
lr1 = 1e-3
lr2 = 1e-1
learn.fit_one_cycle(40,slice(lr1,lr2))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.343330</td>
#       <td>0.854225</td>
#       <td>0.636364</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.694503</td>
#       <td>1.672727</td>
#       <td>0.606061</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.482390</td>
#       <td>0.725037</td>
#       <td>0.878788</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.364987</td>
#       <td>0.141807</td>
#       <td>0.969697</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.287622</td>
#       <td>0.000444</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.239496</td>
#       <td>0.000131</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.202742</td>
#       <td>0.000125</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.173780</td>
#       <td>0.000030</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.151882</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.134215</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.119751</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.107410</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.097001</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.088806</td>
#       <td>0.000046</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.081482</td>
#       <td>0.000134</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.074845</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.068882</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.063605</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.065627</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.060941</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.085119</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.079395</td>
#       <td>0.003812</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.078352</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.082858</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.077826</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.076282</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.072306</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.068080</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.077389</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.073027</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.068978</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.065213</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.068563</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.067721</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.064866</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.062474</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.059795</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.056777</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.053942</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.051277</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Fine-tuning a Pretrained Model with Unfreezing Layers**

# %%
learn.unfreeze()
learn.fit_one_cycle(20,slice(1e-4,1e-3))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.028332</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.013880</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.019208</td>
#       <td>2.272888</td>
#       <td>0.909091</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.018422</td>
#       <td>6.938472</td>
#       <td>0.606061</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.037376</td>
#       <td>26.080133</td>
#       <td>0.363636</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.116967</td>
#       <td>42.659454</td>
#       <td>0.454545</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.098205</td>
#       <td>36.712864</td>
#       <td>0.454545</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.084125</td>
#       <td>31.022728</td>
#       <td>0.575758</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.073197</td>
#       <td>25.551056</td>
#       <td>0.575758</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.070996</td>
#       <td>0.065936</td>
#       <td>0.969697</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.113445</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.103267</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.093269</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.087924</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.080865</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.074139</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.068230</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.063002</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.058347</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.054178</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Plotting Training Loss**

# %%
learn.recorder.plot_loss()

# %% [markdown]
# **Visualizing Confusion Matrix for Model Interpretation**

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Visualizing Top Losses**

# %%
interp.plot_top_losses(6,figsize = (25,5))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
img = PILImage.create('/content/drive/MyDrive/EYE/Test/eye_closed_3test.jpg')
print(learn.predict(img)[0])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# OPEN

# %%
y_prob, y_true = learn.get_preds(dl=learn.dls.valid)
y_pred = y_prob[:, 1] > 0.5
# Out:
# /usr/local/lib/python3.10/dist-packages/fastai/torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.31      0.31        13
#            1       0.55      0.58      0.56        19
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.45        33
#    macro avg       0.29      0.30      0.29        33
# weighted avg       0.44      0.45      0.45        33
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Extracting Positive Class Probabilities and Binarizing True Labels**

# %%
y_prob_positive = y_prob[:, 1]
y_true_bin = label_binarize(y_true, classes=np.unique(y_true))

# %% [markdown]
# **Calculating and Plotting ROC Curve for Multi-Class Classification**

# %%
#Calculating ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(y_prob.shape[1]):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(8, 8))
for i in range(y_prob.shape[1]):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Precision-Recall Curve Analysis for Multi-Class Classification**

# %%
# Calculate precision-recall curve and average precision for each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(y_prob.shape[1]):
    precision[i], recall[i], _ = precision_recall_curve((y_true == i).float(), y_prob[:, i])
    average_precision[i] = average_precision_score((y_true == i).float(), y_prob[:, i])

# Plot precision-recall curve for each class
plt.figure(figsize=(8, 8))
for i in range(y_prob.shape[1]):
    plt.plot(recall[i], precision[i], label=f'Class {i} (Avg Precision = {average_precision[i]:.2f}')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# KNN

# %%
# Define a custom transformer to convert image to a numpy array
class ImageToNumpyArray(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return np.array(X)

# %%
# Extract features from the CNN
X_train, y_train = data.one_batch()
features = learn.model[1][-2].cpu()(X_train)
features = features.view(features.size(0), -1).detach().numpy()

# %%
# Fit the StandardScaler on the training features
scaler = StandardScaler()
features_train_scaled = scaler.fit_transform(features)

# %%
# Create a KNN learner
knn_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))  # You can adjust the number of neighbors (n_neighbors) as needed
])

# %%
# Fit the KNN learner
knn_pipeline.fit(features_train_scaled, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])

# %%
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# Load and preprocess the test image
img = transform(img).unsqueeze(0)  # Assuming `img` is your test image tensor
img_features = learn.model[1][-2].cpu()(img)
img_features = img_features.view(img_features.size(0), -1).detach().numpy()

# %%
# Flatten the test image features
img_features_flat = img_features.reshape(img_features.shape[0], -1)

# %%
# Reshape the array to have a batch dimension
img_features_flat = img_features_flat.reshape(1, -1)

# %%
# Select the first 150528 elements to match the expected number of features
img_features_flat = img_features_flat[:, :150528]

# %%
# Scale the test image features using the same scaler
img_features_scaled = scaler.transform(img_features_flat)

# %%
# Use the KNN classifier to predict the label of the test image
predicted_label = knn_pipeline.predict(img_features_scaled)

print(f"Predicted label: {predicted_label}")
# Out:
# Predicted label: [0]

# %%
predicted_class = data.train.vocab[predicted_label[0]]

print(f"Predicted label: {predicted_class}")
# Out:
# Predicted label: CLOSED
